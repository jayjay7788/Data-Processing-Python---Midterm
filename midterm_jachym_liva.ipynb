# %% [markdown]
# Midterm Python Data Processing - Jáchym Líva

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
import zipfile
import datetime

# %%
print(os.getcwd())
# Out:
# C:\Users\jachy\Desktop\Data-Processing-Python---Midterm

# %%
## Part 1

# %%
## data import

zip_file_path = 'data_midterm.zip'
dfs = list()

with zipfile.ZipFile(zip_file_path, 'r') as z:
    print(z.namelist()) 
    
    csv_filenames = ['data_ws2025/MHK.csv', 'data_ws2025/KR.csv', 'data_ws2025/HST.csv', 'data_ws2025/LOW.csv', 'data_ws2025/RTX.csv']
    
    for file in csv_filenames:
        with z.open(file) as f:
            data = pd.read_csv(f, parse_dates=["Date"], date_format="%Y-%m-%d")
            data['Ticker'] = f'{file}'
            dfs.append(data)
    

returns = pd.concat(dfs, ignore_index=True)
print(returns.tail())

type(returns.Date[0])
# Out:
# ['data_ws2025/MHK.csv', 'data_ws2025/KR.csv', 'data_ws2025/HST.csv', 'data_ws2025/LOW.csv', 'data_ws2025/RTX.csv']
#            Date     Open     High      Low    Close   Volume  Dividends  \
# 5015 2024-12-23  114.514  115.204  114.120  114.948  3588700        0.0
# 5016 2024-12-24  114.278  115.273  114.209  115.145  1663000        0.0
# 5017 2024-12-26  115.086  115.924  114.711  115.352  2147000        0.0
# 5018 2024-12-27  114.593  115.835  114.169  115.027  3847500        0.0
# 5019 2024-12-30  113.775  114.248  112.878  113.558  2822000        0.0
#
#       Stock Splits               Ticker
# 5015           0.0  data_ws2025/RTX.csv
# 5016           0.0  data_ws2025/RTX.csv
# 5017           0.0  data_ws2025/RTX.csv
# 5018           0.0  data_ws2025/RTX.csv
# 5019           0.0  data_ws2025/RTX.csv
# pandas._libs.tslibs.timestamps.Timestamp

# %%
## 1
(returns.High == returns.Low).any()

## there is no such company
# Out:
# np.False_

# %%
## 2 
companies = returns.Ticker.unique()

max_price = []
min_price = []

for company in companies:
    maxp = returns[returns.Ticker == company].High.max() 
    minp = returns[returns.Ticker == company].Low.min() 
    max_price.append(maxp)
    min_price.append(minp)

prices = pd.DataFrame([companies, max_price, min_price])
prices
# Out:
#                      0                   1                    2  \
# 0  data_ws2025/MHK.csv  data_ws2025/KR.csv  data_ws2025/HST.csv
# 1                231.8              62.656               19.522
# 2                76.02              28.403                11.09
#
#                      3                    4
# 0  data_ws2025/LOW.csv  data_ws2025/RTX.csv
# 1              280.185              126.172
# 2              138.062               58.202

# %%
## 3

returns['log_close'] = np.log(returns.Close) 
#returns.head()

summary = pd.DataFrame()

for company in companies:
    summary[f'company'] = returns[returns.Ticker == company].aggregate([np.mean, np.std, np.min, np.max])
# Out:
# C:\Users\jachy\AppData\Local\Temp\ipykernel_15248\3141514450.py:9: FutureWarning: The provided callable <function mean at 0x000001F10A9F3060> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   summary[f'company'] = returns[returns.Ticker == company].aggregate([np.mean, np.std, np.min, np.max])
# C:\Users\jachy\AppData\Local\Temp\ipykernel_15248\3141514450.py:9: FutureWarning: The provided callable <function std at 0x000001F10A9F31A0> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   summary[f'company'] = returns[returns.Ticker == company].aggregate([np.mean, np.std, np.min, np.max])
# C:\Users\jachy\AppData\Local\Temp\ipykernel_15248\3141514450.py:9: FutureWarning: The provided callable <function min at 0x000001F10A9F27A0> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   summary[f'company'] = returns[returns.Ticker == company].aggregate([np.mean, np.std, np.min, np.max])
# C:\Users\jachy\AppData\Local\Temp\ipykernel_15248\3141514450.py:9: FutureWarning: The provided callable <function max at 0x000001F10A9F2660> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   summary[f'company'] = returns[returns.Ticker == company].aggregate([np.mean, np.std, np.min, np.max])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 9
#       6 summary = pd.DataFrame()
#       8 for company in companies:
# ----> 9     summary[f'company'] = returns[returns.Ticker == company].aggregate([np.mean, np.std, np.min, np.max])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10176, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#   10173 axis = self._get_axis_number(axis)
#   10175 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# > 10176 result = op.agg()
#   10177 result = reconstruct_and_relabel_result(result, func, **kwargs)
#   10178 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:928, in FrameApply.agg(self)
#     926 result = None
#     927 try:
# --> 928     result = super().agg()
#     929 finally:
#     930     self.obj = obj
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
#     195 if callable(func):
#     196     f = com.get_cython_func(func)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:326, in Apply.agg_list_like(self)
#     318 def agg_list_like(self) -> DataFrame | Series:
#     319     """
#     320     Compute aggregation in the case of a list-like argument.
#     321
#    (...)    324     Result of aggregation.
#     325     """
# --> 326     return self.agg_or_apply_list_like(op_name="agg")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:744, in NDFrameApply.agg_or_apply_list_like(self, op_name)
#     741 if getattr(obj, "axis", 0) == 1:
#     742     raise NotImplementedError("axis other than 0 is not supported")
# --> 744 keys, results = self.compute_list_like(op_name, obj, kwargs)
#     745 result = self.wrap_results_list_like(keys, results)
#     746 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:385, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     379 colg = obj._gotitem(col, ndim=1, subset=selected_obj.iloc[:, index])
#     380 args = (
#     381     [self.axis, *self.args]
#     382     if include_axis(op_name, colg)
#     383     else self.args
#     384 )
# --> 385 new_res = getattr(colg, op_name)(func, *args, **kwargs)
#     386 results.append(new_res)
#     387 indices.append(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4785, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4782     func = dict(kwargs.items())
#    4784 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4785 result = op.agg()
#    4786 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1425, in SeriesApply.agg(self)
#    1424 def agg(self):
# -> 1425     result = super().agg()
#    1426     if result is None:
#    1427         obj = self.obj
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
#     195 if callable(func):
#     196     f = com.get_cython_func(func)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:326, in Apply.agg_list_like(self)
#     318 def agg_list_like(self) -> DataFrame | Series:
#     319     """
#     320     Compute aggregation in the case of a list-like argument.
#     321
#    (...)    324     Result of aggregation.
#     325     """
# --> 326     return self.agg_or_apply_list_like(op_name="agg")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:744, in NDFrameApply.agg_or_apply_list_like(self, op_name)
#     741 if getattr(obj, "axis", 0) == 1:
#     742     raise NotImplementedError("axis other than 0 is not supported")
# --> 744 keys, results = self.compute_list_like(op_name, obj, kwargs)
#     745 result = self.wrap_results_list_like(keys, results)
#     746 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:369, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     363 colg = obj._gotitem(selected_obj.name, ndim=1, subset=selected_obj)
#     364 args = (
#     365     [self.axis, *self.args]
#     366     if include_axis(op_name, colg)
#     367     else self.args
#     368 )
# --> 369 new_res = getattr(colg, op_name)(a, *args, **kwargs)
#     370 results.append(new_res)
#     372 # make sure we find a good name
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4785, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4782     func = dict(kwargs.items())
#    4784 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4785 result = op.agg()
#    4786 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1425, in SeriesApply.agg(self)
#    1424 def agg(self):
# -> 1425     result = super().agg()
#    1426     if result is None:
#    1427         obj = self.obj
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:199, in Apply.agg(self)
#     197     if f and not args and not kwargs:
#     198         warn_alias_replacement(obj, func, f)
# --> 199         return getattr(obj, f)()
#     201 # caller can react
#     202 return None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string 'data_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025/MHK.csvdata_ws2025 ...

# %%
## 4

# %%
## 5

# %%
## 6 

returns.iloc[returns['log_close'].idxmin()]['Ticker']
# Out:
# 'data_ws2025/HST.csv'

# %%
## 7

# %%
## 8

# %%
##### Part 2

# %%
## import
